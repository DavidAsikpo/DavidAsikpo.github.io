# %%
import pandas as pd
df = pd.read_csv("A_B_testing_dataset.csv")

# %%
df.head()
# Out:
#   date_of_campaign facebook_ad_campaign  facebook_ad_views  \
# 0       2021-12-22          FACEBOOK AD               3172
# 1       2021-12-24          FACEBOOK AD               3211
# 2       2021-12-25          FACEBOOK AD               1936
# 3       2021-12-25          FACEBOOK AD               1194
# 4       2021-12-26          FACEBOOK AD               2479
#
#    facebook_ad_clicks  facebook_ad_conversions  facebook_cost_per_ad  \
# 0                  62                       14                   141
# 1                  38                        9                   186
# 2                  53                       15                    66
# 3                  45                        9                    71
# 4                  44                       12                   174
#
#    facebook_ctr  facebook_conversion_rate  facebook_cost_per_click  \
# 0          1.95                     22.58                     2.27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date_of_campaign          1000 non-null   object
#  1   facebook_ad_campaign      1000 non-null   object
#  2   facebook_ad_views         1000 non-null   int64
#  3   facebook_ad_clicks        1000 non-null   int64
#  4   facebook_ad_conversions   1000 non-null   int64
#  5   facebook_cost_per_ad      1000 non-null   int64
#  6   facebook_ctr              1000 non-null   float64
#  7   facebook_conversion_rate  1000 non-null   float64
#  8   facebook_cost_per_click   1000 non-null   float64
#  9   adword_ad_campaign        1000 non-null   object
#  10  adword_ad_views           1000 non-null   int64
#  11  adword_ad_clicks          1000 non-null   int64
#  12  adword_ad_conversions     1000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['date_of_campaign', 'facebook_ad_campaign', 'facebook_ad_views',
#        'facebook_ad_clicks', 'facebook_ad_conversions', 'facebook_cost_per_ad',
#        'facebook_ctr', 'facebook_conversion_rate', 'facebook_cost_per_click',
#        'adword_ad_campaign', 'adword_ad_views', 'adword_ad_clicks',
#        'adword_ad_conversions', 'adword_cost_per_ad', 'adword_ctr',
#        'adword_conversion_rate', 'adword_cost_per_click'],
#       dtype='object')

# %%
facebook = df[['date_of_campaign', 'facebook_ad_campaign', 'facebook_ad_views',
       'facebook_ad_clicks', 'facebook_ad_conversions', 'facebook_cost_per_ad',
       'facebook_ctr', 'facebook_conversion_rate', 'facebook_cost_per_click']]

facebook.head()
# Out:
#   date_of_campaign facebook_ad_campaign  facebook_ad_views  \
# 0       2021-12-22          FACEBOOK AD               3172
# 1       2021-12-24          FACEBOOK AD               3211
# 2       2021-12-25          FACEBOOK AD               1936
# 3       2021-12-25          FACEBOOK AD               1194
# 4       2021-12-26          FACEBOOK AD               2479
#
#    facebook_ad_clicks  facebook_ad_conversions  facebook_cost_per_ad  \
# 0                  62                       14                   141
# 1                  38                        9                   186
# 2                  53                       15                    66
# 3                  45                        9                    71
# 4                  44                       12                   174
#
#    facebook_ctr  facebook_conversion_rate  facebook_cost_per_click
# 0          1.95                     22.58                     2.27
# ...

# %%
facebook.rename(
    columns={
        'facebook_ad_campaign': 'Ad Campaign',
        'facebook_ad_views': 'Ad Views',
        'facebook_ad_clicks': 'Ad Clicks',
        'facebook_ad_conversions': 'Ad Conversions',
        'facebook_cost_per_ad': 'Cost Per Ad',
        'facebook_ctr': 'Ctr',
        'facebook_conversion_rate': 'Conversion Rate',
        'facebook_cost_per_click': 'Cost per Click'
    },
    inplace=True
)
# Out:
# C:\Users\Princess Tusche Esty\AppData\Local\Temp\ipykernel_2356\2288353093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   facebook.rename(

# %%
adword = df[['date_of_campaign','adword_ad_campaign', 'adword_ad_views', 'adword_ad_clicks',
       'adword_ad_conversions', 'adword_cost_per_ad', 'adword_ctr',
       'adword_conversion_rate', 'adword_cost_per_click']]

adword.head()
# Out:
#   date_of_campaign adword_ad_campaign  adword_ad_views  adword_ad_clicks  \
# 0       2021-12-22          ADWORD AD             5754                64
# 1       2021-12-24          ADWORD AD             4954                73
# 2       2021-12-25          ADWORD AD             4702                38
# 3       2021-12-25          ADWORD AD             3718                58
# 4       2021-12-26          ADWORD AD             5562                63
#
#    adword_ad_conversions  adword_cost_per_ad  adword_ctr  \
# 0                      9                 177        1.11
# 1                      6                  54        1.47
# 2                      9                 187        0.81
# 3                      3                 161        1.56
# 4                      4                 162        1.13
#
#    adword_conversion_rate  adword_cost_per_click
# 0                   14.06                   2.77
# 1                    8.22                   0.74
# ...

# %%
adword.rename(
    columns={
        'adword_ad_campaign': 'Ad Campaign',
        'adword_ad_views': 'Ad Views',
        'adword_ad_clicks': 'Ad Clicks',
        'adword_ad_conversions': 'Ad Conversions',
        'adword_cost_per_ad': 'Cost Per Ad',
        'adword_ctr': 'Ctr',
        'adword_conversion_rate': 'Conversion Rate',
        'adword_cost_per_click': 'Cost per Click'
    },
    inplace=True
)
# Out:
# C:\Users\Princess Tusche Esty\AppData\Local\Temp\ipykernel_2356\2368330010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adword.rename(

# %%
merged_dataset = pd.concat([facebook,adword], axis=0)

merged_dataset.shape
# Out:
# (2000, 9)

# %%
merged_dataset.to_csv("merged_ab_test_data.csv", index = False)

# %%
merged_dataset.head()
# Out:
#   date_of_campaign  Ad Campaign  Ad Views  Ad Clicks  Ad Conversions  \
# 0       2021-12-22  FACEBOOK AD      3172         62              14
# 1       2021-12-24  FACEBOOK AD      3211         38               9
# 2       2021-12-25  FACEBOOK AD      1936         53              15
# 3       2021-12-25  FACEBOOK AD      1194         45               9
# 4       2021-12-26  FACEBOOK AD      2479         44              12
#
#    Cost Per Ad   Ctr  Conversion Rate  Cost per Click
# 0          141  1.95            22.58            2.27
# 1          186  1.18            23.68            4.89
# 2           66  2.74            28.30            1.25
# 3           71  3.77            20.00            1.58
# 4          174  1.77            27.27            3.95

# %%
merged_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_of_campaign  2000 non-null   object
#  1   Ad Campaign       2000 non-null   object
#  2   Ad Views          2000 non-null   int64
#  3   Ad Clicks         2000 non-null   int64
#  4   Ad Conversions    2000 non-null   int64
#  5   Cost Per Ad       2000 non-null   int64
#  6   Ctr               2000 non-null   float64
#  7   Conversion Rate   2000 non-null   float64
#  8   Cost per Click    2000 non-null   float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 156.2+ KB

# %%
agg = merged_dataset.groupby('Ad Campaign').agg({'Ad Clicks':'sum', 'Ad Views':'sum'})

clicks = agg['Ad Clicks'].values
views = agg['Ad Views'].values

print("Clicks:", clicks)
print("Views:", views)
# Out:
# Clicks: [60128 44196]
# Views: [4771438 2152031]

# %%
z_stat, p_value = proportions_ztest(count=clicks, nobs=views)

print("CTR Z-statistic:", z_stat)
print("CTR P-value:", p_value)
# Out:
# CTR Z-statistic: -79.325545019369
# CTR P-value: 0.0

# %%
agg
# Out:
#              Ad Clicks  Ad Views
# Ad Campaign
# ADWORD AD        60128   4771438
# FACEBOOK AD      44196   2152031
